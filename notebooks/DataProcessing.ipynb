# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("../Bangladesh_Multi_Site_Air_Quality.csv")

# %%
df.head()
# Out:
#    No  year  month  day  hour  PM2.5  PM10   SO2   NO2     CO    O3  TEMP  \
# 0   1  2022      8    4     0   15.1  21.8  11.9  28.9  262.0  13.0  26.8
# 1   2  2022      8    4     1   11.6  16.8  12.1  25.1  245.0  18.0  27.7
# 2   3  2022      8    4     2   11.8  17.1  12.3  19.5  221.0  25.0  28.4
# 3   4  2022      8    4     3    9.2  13.5  12.1  13.2  193.0  35.0  29.2
# 4   5  2022      8    4     4    9.0  13.2  11.1  10.5  180.0  43.0  30.2
#
#      PRES  DEWP  RAIN  wd  WSPM station
# 0  1002.5  25.2   0.0  SE  2.78   Dhaka
# 1  1003.2  25.0   0.0  SE  3.61   Dhaka
# 2  1003.4  24.8   0.0  SE  4.33   Dhaka
# 3  1003.5  25.0   0.0  SE  3.94   Dhaka
# 4  1003.9  25.3   0.1  SE  3.61   Dhaka

# %%
df.shape
# Out:
# (208368, 18)

# %%
df.columns
# Out:
# Index(['No', 'year', 'month', 'day', 'hour', 'PM2.5', 'PM10', 'SO2', 'NO2',
#        'CO', 'O3', 'TEMP', 'PRES', 'DEWP', 'RAIN', 'wd', 'WSPM', 'station'],
#       dtype='str')

# %%
df.isnull().sum()
# Out:
# No         0
# year       0
# month      0
# day        0
# hour       0
# PM2.5      0
# PM10       0
# SO2        0
# NO2        0
# CO         0
# O3         0
# TEMP       0
# PRES       0
# DEWP       0
# RAIN       0
# wd         0
# WSPM       0
# station    0
# dtype: int64

# %%
df.describe()
# Out:
#                   No           year          month            day  \
# count  208368.000000  208368.000000  208368.000000  208368.000000
# mean   104184.500000    2024.070491       6.516240      15.680028
# std     60150.804783       1.212359       3.464446       8.770332
# min         1.000000    2022.000000       1.000000       1.000000
# 25%     52092.750000    2023.000000       4.000000       8.000000
# 50%    104184.500000    2024.000000       6.000000      16.000000
# 75%    156276.250000    2025.000000      10.000000      23.000000
# max    208368.000000    2026.000000      12.000000      31.000000
#
#                 hour          PM2.5           PM10            SO2  \
# count  208368.000000  208368.000000  208368.000000  208368.000000
# mean       11.500000      43.234646      56.961416       7.295156
# std         6.922203      32.274409      40.281970       5.717566
# min         0.000000       0.400000       0.500000       0.000000
# 25%         5.750000      17.800000      24.600000       2.900000
# 50%        11.500000      35.700000      48.500000       6.000000
# 75%        17.250000      60.100000      79.400000      10.000000
# max        23.000000     312.000000     394.900000      77.700000
#
#                  NO2             CO             O3           TEMP  \
# count  208368.000000  208368.000000  208368.000000  208368.000000
# mean       14.324695     430.113122      82.465153      25.556723
# std        15.430669     259.939074      44.008952       5.007792
# min         0.000000      58.000000      -4.000000       8.500000
# 25%         4.200000     238.000000      51.000000      22.700000
# 50%         9.500000     358.000000      73.000000      26.400000
# 75%        18.600000     566.000000     109.000000      28.900000
# max       178.100000    4134.000000     311.000000      43.600000
#
#                 PRES           DEWP           RAIN           WSPM
# count  208368.000000  208368.000000  208368.000000  208368.000000
# mean     1006.960218      21.013430       0.249155       2.356235
# std         5.627742       4.997699       1.096855       1.326852
# min       978.600000       2.500000       0.000000       0.000000
# 25%      1002.600000      16.500000       0.000000       1.480000
# 50%      1007.300000      22.900000       0.000000       2.100000
# 75%      1011.500000      25.300000       0.000000       2.950000
# max      1021.300000      29.800000      42.100000      17.080000

# %%
df.columns
# Out:
# Index(['No', 'year', 'month', 'day', 'hour', 'PM2.5', 'PM10', 'SO2', 'NO2',
#        'CO', 'O3', 'TEMP', 'PRES', 'DEWP', 'RAIN', 'wd', 'WSPM', 'station'],
#       dtype='str')

# %%
df['PM2.5'].describe()
# Out:
# count    208368.000000
# mean         43.234646
# std          32.274409
# min           0.400000
# 25%          17.800000
# 50%          35.700000
# 75%          60.100000
# max         312.000000
# Name: PM2.5, dtype: float64

# %%
plt.figure(figsize=(9, 7))
sns.boxplot(x='station',y='PM2.5',data=df)
#df.boxplot(column="PM2.5", by="station", rot=45)
plt.title("PM2.5 distribution by city")
plt.suptitle("")
plt.ylabel("PM2.5 (ug/m3)")
plt.tight_layout()

# %%
plt.figure(figsize=(10, 5))

sns.lineplot(
    data=df,
    x="hour",
    y="PM2.5",
    estimator="mean",
    errorbar=None,
    marker="o"
)

plt.title("Mean PM2.5 by Hour of Day")
plt.xlabel("Hour")
plt.ylabel("Mean PM2.5")
plt.xticks(range(24))
plt.grid(alpha=0.3)
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(10, 8))
sns.heatmap(df.corr(numeric_only=True),annot=True,cmap='coolwarm',fmt=".2f")
# Out:
# <Axes: >

# %%
# Out:
#              No          year         month           day          hour  \
# No     1.000000  1.618963e-01 -1.970906e-02 -1.335272e-04  1.150808e-04
# year   0.161896  1.000000e+00 -3.499178e-01 -2.309715e-02 -1.439640e-15
# month -0.019709 -3.499178e-01  1.000000e+00  1.075877e-02  3.505023e-16
# day   -0.000134 -2.309715e-02  1.075877e-02  1.000000e+00  1.547134e-17
# hour   0.000115 -1.439640e-15  3.505023e-16  1.547134e-17  1.000000e+00
# PM2.5  0.042432  7.922621e-02 -2.143265e-01  1.981410e-02  9.493311e-02
# PM10   0.013350 -7.215745e-02 -2.255605e-01  2.054172e-02  8.307977e-02
# SO2   -0.135691 -4.144073e-02 -1.289419e-01 -1.960595e-02 -4.522253e-02
# NO2   -0.178104 -1.183698e-01  2.014604e-02  2.225361e-02  2.763879e-01
# CO    -0.059683  6.602549e-02 -8.568196e-02  1.376070e-02  1.274131e-01
# O3     0.004533  9.616602e-02 -1.499702e-01 -1.441300e-02 -3.379412e-01
# TEMP   0.000804  3.753505e-03  1.042678e-01  5.511909e-03 -2.581381e-01
# PRES   0.049225 -1.971180e-02 -9.982066e-02 -2.489096e-02 -6.915855e-02
